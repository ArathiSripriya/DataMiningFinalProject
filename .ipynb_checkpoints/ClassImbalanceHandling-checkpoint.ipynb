# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
from time import sleep
import os
import numpy as np
import sklearn as sk
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
import time

from amb_sdk.sdk import DarwinSdk

# %%
# Login
ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
ds.auth_login_user('vargasbri2@gmail.com', 'qNuNeX5JGY')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTU5ODk4NDEsImlhdCI6MTU1NTk4MjY0MSwibmJmIjoxNTU1OTgyNjQxLCJqdGkiOiIzN2Q4NzRlZi1hNjBjLTRhMjktODgwMi0xZGUyN2M1OWVlNjQiLCJpZGVudGl0eSI6Ijc2NmRiM2JjLTRmMzUtMTFlOS1iMzEwLTc3ZWRkN2EzNzNhOSIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.TcrSy3XjTUHirk_iE7Xvn1GJvsi6eZLVPEBln2N_4kQ')

# %%
combined_filename = 'COMBINEDDATA.csv'
df = pd.read_csv(combined_filename)
df.head()
# Out:
#   State_And_County_FIPS_Code CHSI_State_Name CHSI_County_Name  \
# 0                        1-1         Alabama          Autauga
# 1                        1-3         Alabama          Baldwin
# 2                        1-5         Alabama          Barbour
# 3                        1-7         Alabama             Bibb
# 4                        1-9         Alabama           Blount
#
#    Population_Size Population_Density Poverty  Age_19_Under  Age_19_64  \
# 0            48612                 82    10.4          26.9       62.3
# 1           162586                102    10.2          23.5       60.3
# 2            28414                 32    22.1          24.3       62.5
# 3            21516                 35    16.8          24.6       63.3
# 4            55725                 86    11.9          24.5       62.1
#
#    Age_65_84  Age_85_and_Over   ...     Pert_Rpt  Pert_Exp  Syphilis_Rpt  \
# 0        9.8              0.9   ...            3        11             8
# 1       14.5              1.8   ...            0        27             0
# 2       11.6              1.6   ...            0         6             6
# 3       10.9              1.2   ...            3         6             2
# 4       12.1              1.3   ...            3         8             0
#
#    Syphilis_Exp  No_Exercise Obesity Smoker Diabetes Uninsured HPSA_Ind
# 0             2         27.8    24.5   26.6     14.2      5690        2
# 1             4         27.2    23.6   24.6      7.2     19798        2
# 2             3            -    25.6   17.7      6.6      5126        2
# 3             6            -       -      -     13.1      3315        1
# 4             3         33.5    24.2   23.6      8.4      8131        1
#
# [5 rows x 57 columns]

# %%
ones_df = df.loc[df['HPSA_Ind'] == 1]
twos_df = df.loc[df['HPSA_Ind'] == 2]
print(len(ones_df))
print(len(twos_df))
# Out:
# 757
# 2384
