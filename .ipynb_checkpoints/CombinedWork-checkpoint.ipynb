# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
from time import sleep
import os
import numpy as np
import sklearn as sk
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
import time

from amb_sdk.sdk import DarwinSdk

# %%
# Login
ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
ds.auth_login_user('vargasbri2@gmail.com', 'qNuNeX5JGY')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTU5ODAyMDUsImlhdCI6MTU1NTk3MzAwNSwibmJmIjoxNTU1OTczMDA1LCJqdGkiOiJkYTJmMzBiMi0wZTJkLTRiNTctYmY5MS0xNDRjZGY1N2MzNmQiLCJpZGVudGl0eSI6Ijc2NmRiM2JjLTRmMzUtMTFlOS1iMzEwLTc3ZWRkN2EzNzNhOSIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.JrRpw5izrVHb-g8PQcDmBLUZbnIng27jubKYA3YTHCc')

# %%
#Removing Meas_Rpt, Meas_Exp, CRS_Rpt, CRS_Exp because not a lot of varying data
#Removing for too many missing values: High_Blood_Pres (0.515441), Few_Fruit_Veg (0.393824)
#Removed state and county names because not numerical
df_list = []
labels_col = 'HPSA_Ind'


def create_new_df(dataset_name, column_names):
    df = pd.read_csv(dataset_name)
    return df[column_names]

def merge_state_and_county_codes(df):
    df["State_And_County_FIPS_Code"] = df["State_FIPS_Code"].map(str) + "-" + df["County_FIPS_Code"].map(str)
    df = df.drop(columns = ['State_FIPS_Code', 'County_FIPS_Code'])
    return df

def sample_help():
    global df_list
    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'Population_Size','Population_Density','Poverty','Age_19_Under','Age_19_64','Age_65_84','Age_85_and_Over','White','Black','Native_American','Asian','Hispanic']
    demographics_df = create_new_df("DEMOGRAPHICS.csv", col_names)
    df_list.append(demographics_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'ALE', 'Health_Status']
    summ_meas_health_df = create_new_df("SUMMARYMEASURESOFHEALTH.csv", col_names)
    df_list.append(summ_meas_health_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'LBW','VLBW','Premature','Under_18','Over_40','Late_Care','Infant_Mortality','Unmarried','Brst_Cancer','Col_Cancer','CHD','Lung_Cancer','Suicide']
    meas_birth_and_death_df = create_new_df("MEASURESOFBIRTHANDDEATH.csv", col_names)
    df_list.append(meas_birth_and_death_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'No_HS_Diploma','Unemployed','Sev_Work_Disabled','Major_Depression','Recent_Drug_Use','Ecol_Rpt','Ecol_Exp','Salm_Rpt','Salm_Exp','Shig_Rpt','Shig_Exp']
    vuln_pop_and_env_health_df = create_new_df("VUNERABLEPOPSANDENVHEALTH.csv", col_names)
    df_list.append(vuln_pop_and_env_health_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'FluB_Rpt','FluB_Exp','HepA_Rpt','HepA_Exp','HepB_Rpt','HepB_Exp','Pert_Rpt','Pert_Exp','Syphilis_Rpt','Syphilis_Exp']
    prev_services_df = create_new_df("PREVENTIVESERVICESUSE.csv", col_names)
    df_list.append(prev_services_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'No_Exercise','Obesity','Smoker','Diabetes','Uninsured', labels_col]
    risk_factors_df = create_new_df("RISKFACTORSANDACCESSTOCARE.csv", col_names)
    df_list.append(risk_factors_df)
    
    #Merges State and County Codes for each df
    for df_idx in range(len(df_list)):
        df_list[df_idx] = merge_state_and_county_codes(df_list[df_idx])
        
def my_sample(n):
    global df_list
    sample_help()
    df_list = [df.set_index("State_And_County_FIPS_Code") for df in df_list]
    merged_df = df_list[0].join(df_list[1:])
    smaller_sample = merged_df.sample(n)
    smaller_sample.head()
    smaller_sample.to_csv('SAMPLEDDATASET.csv')
    

# my_sample(2000)

# %%
# print(len(merged_df))

# %%
#START HERE - after creating SAMPLEDDATASET
filename = 'SAMPLEDDATASET.csv'
merged_df = pd.read_csv(filename, index_col='State_And_County_FIPS_Code')

# %%
merged_df = merged_df.replace([-9999, -9998.9, -2222.2, -2222, -1111.1, -1111, -2, -1], np.nan)
# merged_df.drop(columns=['State_And_County_FIPS_Code']) #Only needed for merging
merged_df.head()
# Out:
#                             Population_Size  Population_Density  Poverty  \
# State_And_County_FIPS_Code
# 48-267                                 4591                   4     17.1
# 5-129                                  7969                  12     21.8
# 48-481                                41554                  38     15.6
# 26-39                                 15074                  27     12.5
# 45-35                                112858                 196     11.2
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                              23.1       57.2       17.6
# 5-129                               20.9       59.3       16.9
# 48-481                              28.8       57.5       11.8
# 26-39                               22.3       61.1       14.6
# 45-35                               26.6       63.9        8.6
#
#                             Age_85_and_Over  White  Black  Native_American  \
# State_And_County_FIPS_Code
# 48-267                                  2.0   98.3    0.5              0.4
# 5-129                                   2.9   98.0    0.2              0.8
# 48-481                                  1.8   84.2   14.5              0.5
# 26-39                                   2.0   95.9    2.5              0.7
# 45-35                                   1.0   71.4   25.2              0.7
#
#                               ...     Pert_Rpt  Pert_Exp  Syphilis_Rpt  \
# State_And_County_FIPS_Code    ...
# 48-267                        ...            0         3             0
# 5-129                         ...           21         2             0
# 48-481                        ...            1         6             8
# 26-39                         ...            1         1             0
# 45-35                         ...           12        10             4
#
#                             Syphilis_Exp  No_Exercise  Obesity  Smoker  \
# State_And_County_FIPS_Code
# 48-267                                 0          NaN      NaN     NaN
# 5-129                                  1         28.6      NaN    23.5
# 48-481                                 4          NaN      NaN    15.6
# 26-39                                  4          NaN      NaN     NaN
# 45-35                                  5         25.3     27.0    22.1
#
#                             Diabetes  Uninsured  HPSA_Ind
# State_And_County_FIPS_Code
# 48-267                           NaN      965.0         2
# 5-129                           12.4     2118.0         2
# 48-481                          11.8     7845.0         2
# 26-39                           10.3     1973.0         2
# 45-35                            7.1    12899.0         2
#
# [5 rows x 54 columns]

# %%
#Imputation
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
filled_data = imp.fit_transform(merged_df)
filled_df = pd.DataFrame(filled_data, columns=merged_df.columns)

df_feats = filled_df.loc[:, filled_df.columns != labels_col]
df_labels = merged_df.iloc[:, merged_df.columns == labels_col]
df_feats.head()

# merged_df.dropna(inplace=True)
# # new_merged_df = merged_df[merged_df.columns != 'State_And_County_FIPS_Code'] #only used to join datasets
# # merged_df = merged_df.loc[:, merged_df.columns != 'State_And_County_FIPS_Code']
# df_feats = merged_df.loc[:, merged_df.columns != labels_col]
# df_labels = merged_df.iloc[:, merged_df.columns == labels_col]

# print(len(merged_df))
# merged_df.head()
# Out:
#    Population_Size  Population_Density  Poverty  Age_19_Under  Age_19_64  \
# 0           4591.0                 4.0     17.1          23.1       57.2
# 1           7969.0                12.0     21.8          20.9       59.3
# 2          41554.0                38.0     15.6          28.8       57.5
# 3          15074.0                27.0     12.5          22.3       61.1
# 4         112858.0               196.0     11.2          26.6       63.9
#
#    Age_65_84  Age_85_and_Over  White  Black  Native_American    ...      \
# 0       17.6              2.0   98.3    0.5              0.4    ...
# 1       16.9              2.9   98.0    0.2              0.8    ...
# 2       11.8              1.8   84.2   14.5              0.5    ...
# 3       14.6              2.0   95.9    2.5              0.7    ...
# 4        8.6              1.0   71.4   25.2              0.7    ...
#
#    HepB_Exp  Pert_Rpt  Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# 0       2.0       0.0       3.0           0.0           0.0    26.633262
# 1       2.0      21.0       2.0           0.0           1.0    28.600000
# 2       4.0       1.0       6.0           8.0           4.0    26.633262
# 3       4.0       1.0       1.0           0.0           4.0    26.633262
# 4      15.0      12.0      10.0           4.0           5.0    25.300000
#
#      Obesity    Smoker   Diabetes  Uninsured
# 0  24.168887  23.11587   7.796638      965.0
# 1  24.168887  23.50000  12.400000     2118.0
# 2  24.168887  15.60000  11.800000     7845.0
# 3  24.168887  23.11587  10.300000     1973.0
# 4  27.000000  22.10000   7.100000    12899.0
#
# [5 rows x 53 columns]

# %%
#Perform standardization
scaler = sk.preprocessing.StandardScaler(with_mean=0, with_std=1)
standardized_data = scaler.fit_transform(df_feats)
standardized_df = pd.DataFrame(standardized_data, columns=df_feats.columns, index=merged_df.index)
# print(standardized_data)
standardized_df.head()
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 48-267                             0.014481            0.003833  3.477367
# 5-129                              0.025136            0.011498  4.433135
# 48-481                             0.131071            0.036411  3.172335
# 26-39                              0.047547            0.025871  2.541935
# 45-35                              0.355980            0.187804  2.277574
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                          7.181861  16.667614   5.333130
# 5-129                           6.497874  17.279537   5.121017
# 48-481                          8.954008  16.755032   3.575622
# 26-39                           6.933138  17.804042   4.424074
# 45-35                           8.270021  18.619940   2.605961
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 48-267                             2.117243  6.135751  0.034151
# 5-129                              3.070002  6.117025  0.013660
# 48-481                             1.905518  5.255648  0.990370
# 26-39                              2.117243  5.985946  0.170754
# 45-35                              1.058621  4.456690  1.721196
#
#                             Native_American    ...      HepB_Exp  Pert_Rpt  \
# State_And_County_FIPS_Code                     ...
# 48-267                             0.059450    ...      0.072501  0.000000
# 5-129                              0.118900    ...      0.072501  0.548360
# 48-481                             0.074313    ...      0.145003  0.026112
# 26-39                              0.104038    ...      0.145003  0.026112
# 45-35                              0.104038    ...      0.543760  0.313349
#
#                             Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# State_And_County_FIPS_Code
# 48-267                      0.107772       0.00000      0.000000     4.754315
# 5-129                       0.071848       0.00000      0.027419     5.105399
# 48-481                      0.215545       0.16844      0.109676     4.754315
# 26-39                       0.035924       0.00000      0.109676     4.754315
# 45-35                       0.359242       0.08422      0.137095     4.516314
#
#                              Obesity    Smoker  Diabetes  Uninsured
# State_And_County_FIPS_Code
# 48-267                      5.877071  4.667118  3.073575   0.016117
# 5-129                       5.877071  4.744674  4.888304   0.035374
# 48-481                      5.877071  3.149656  4.651773   0.131024
# 26-39                       5.877071  4.667118  4.060446   0.032952
# 45-35                       6.565504  4.462013  2.798948   0.215434
#
# [5 rows x 53 columns]

# %%
#Perform PCA to reduce dimensionality
pca = PCA()

pca_data = pca.fit_transform(standardized_df)
pca_df = pd.DataFrame(pca_data, columns=standardized_df.columns, index=merged_df.index)
pca_df.head()
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 48-267                            -1.566259            0.560488  1.384149
# 5-129                             -1.724290            1.749549  2.690684
# 48-481                            -0.607729            1.181050 -0.494776
# 26-39                             -1.374806            0.848758  0.604481
# 45-35                              0.925710            0.997256 -2.226410
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                          2.537828   0.746897  -0.212123
# 5-129                          -0.408630   0.086359  -0.712735
# 48-481                          3.585611  -0.045433  -0.219206
# 26-39                          -0.790270   0.797244   0.894896
# 45-35                          -1.105993  -0.525132   0.820031
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 48-267                            -0.898175  1.055979 -0.332058
# 5-129                              0.025589  1.764069 -1.797602
# 48-481                            -1.677337  0.141064 -0.034358
# 26-39                              0.963442  0.710223 -0.328074
# 45-35                             -0.501999 -0.607889  0.270041
#
#                             Native_American    ...      HepB_Exp  Pert_Rpt  \
# State_And_County_FIPS_Code                     ...
# 48-267                            -0.743536    ...      0.015112  0.008016
# 5-129                              0.013359    ...      0.064116  0.042749
# 48-481                            -0.102473    ...      0.047867 -0.035978
# 26-39                              0.339749    ...     -0.038447 -0.048551
# 45-35                              1.427288    ...     -0.139831 -0.015536
#
#                             Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# State_And_County_FIPS_Code
# 48-267                     -0.100886      0.004580      0.027538    -0.022406
# 5-129                      -0.002686     -0.016248      0.083492     0.001213
# 48-481                     -0.039264      0.047840     -0.072165     0.028307
# 26-39                       0.165967     -0.029711      0.020112    -0.018684
# 45-35                       0.228784     -0.046414     -0.061755    -0.070643
#
#                              Obesity    Smoker  Diabetes  Uninsured
# State_And_County_FIPS_Code
# 48-267                      0.036761 -0.022201 -0.000262   0.013927
# 5-129                       0.008180  0.007419 -0.011467  -0.000126
# 48-481                     -0.036187 -0.012980  0.008641   0.019483
# 26-39                       0.027932 -0.011239 -0.002515  -0.002862
# 45-35                       0.154130  0.006802  0.027216  -0.017928
#
# [5 rows x 53 columns]

# %%
#Concatenate original labels that were removed for standardization and PCA
# df_labels.head()

pca_df = pca_df.join(df_labels[labels_col])

pca_df.head()
# print(merged_df[labels_col])

# %%
#Split Data
data_feats = pca_df.loc[:, pca_df.columns != labels_col]
data_labels = pca_df.iloc[:, pca_df.columns == labels_col]

#Using 80-20 split
train_feats,test_feats, train_labels, test_labels = sk.model_selection.train_test_split(data_feats, data_labels, test_size=0.2)
print(test_labels)
train_data = train_feats.join(train_labels)
test_data = test_feats.join(test_labels)

train_dataset_filename = "TRAINDATA.csv"
test_dataset_filename = "TESTDATA.csv" 

train_data.to_csv(train_dataset_filename)
test_data.to_csv(test_dataset_filename)

# train_data.head()
print(len(train_data))
print(len(test_data))
# Out:
#                             HPSA_Ind
# State_And_County_FIPS_Code
# 37-57                              2
# 18-131                             2
# 38-65                              1
# 21-71                              2
# 42-43                              2
# 6-103                              2
# 37-19                              2
# 21-85                              2
# 25-13                              2
# 27-9                               2
# 13-179                             1
# 28-131                             2
# 36-115                             2
# 1-37                               1
# 39-55                              2
# 8-123                              2
# 17-53                              2
# 48-123                             2
# 54-63                              1
# 27-169                             2
# 21-61                              2
# 31-43                              2
# 22-51                              2
# 39-9                               2
# 40-11                              2
# 38-81                              1
# 13-219                             2
# 47-187                             2
# 16-33                              1
# 6-97                               2
# ...                              ...
# 1-75                               2
# 6-59                               2
# 19-11                              1
# 29-23                              2
# 28-31                              1
# 35-29                              2
# 48-223                             2
# 37-169                             2
# 17-115                             2
# 42-57                              2
# 16-31                              2
# 51-730                             2
# 17-105                             2
# 55-119                             2
# 29-209                             2
# 40-31                              2
# 51-678                             2
# 20-139                             1
# 13-101                             1
# 41-1                               2
# 48-373                             1
# 40-111                             2
# 6-5                                2
# 5-67                               2
# 45-79                              2
# 31-33                              2
# 17-43                              2
# 1-13                               2
# 55-27                              2
# 42-95                              2
#
# [400 rows x 1 columns]
# 1600
# 400

# %%
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 37-57                              0.049686            1.638534  0.055252
# 18-131                            -1.063614           -0.732965  0.825446
# 38-65                             -1.212272           -2.417869 -0.320022
# 21-71                             -1.656899            4.130384  2.695050
# 42-43                              2.011499           -0.056915 -1.710359
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 37-57                          -1.237937  -0.935885   0.037039
# 18-131                         -0.260402   0.408040   0.239694
# 38-65                          -1.549769  -0.293887   0.814513
# 21-71                          -2.852299  -3.783047  -1.141988
# 42-43                          -0.881376   0.954935  -0.300064
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 37-57                             -0.850407 -0.348531 -0.600115
# 18-131                             0.418987 -0.839100  0.522270
# 38-65                              0.112130  0.442625 -0.097890
# 21-71                             -0.013517  0.468367 -0.258204
# 42-43                             -0.000306 -0.841981 -0.251079
#
#                             Native_American    ...     Pert_Rpt  Pert_Exp  \
# State_And_County_FIPS_Code                     ...
# 37-57                              0.611441    ...     0.022599 -0.213576
# 18-131                             0.080937    ...    -0.016542  0.041452
# 38-65                              1.201952    ...     0.015879  0.027734
# 21-71                             -0.805748    ...    -0.002925  0.003997
# 42-43                              0.036916    ...     0.028947 -0.227201
#
#                             Syphilis_Rpt  Syphilis_Exp  No_Exercise   Obesity  \
# State_And_County_FIPS_Code
# 37-57                          -0.033946      0.017509     0.119311 -0.002420
# 18-131                         -0.001714      0.001624     0.013593 -0.041475
# 38-65                          -0.016807      0.073328    -0.018686  0.028050
# 21-71                           0.116943     -0.108429     0.069227 -0.100040
# 42-43                           0.066368     -0.037545     0.072048 -0.095497
#
#                               Smoker  Diabetes  Uninsured  HPSA_Ind
# State_And_County_FIPS_Code
# 37-57                       0.005451 -0.016407   0.000911         2
# 18-131                     -0.016073  0.004934   0.016389         2
# 38-65                       0.002350 -0.008697   0.001034         1
# 21-71                      -0.006209  0.004300   0.002092         2
# 42-43                      -0.000481 -0.035719   0.000888         2
#
# [5 rows x 54 columns]

# %%
train_dataset_name = "healthcare-training-data"

status, dataset = ds.delete_dataset(train_dataset_name)
print(dataset)
status, dataset = ds.upload_dataset(train_dataset_filename, train_dataset_name)
if not status:
    print(dataset)
# Out:
# 404: NOT FOUND - {"message": "Dataset name not found"}

# %%
print(status)
print(dataset)
train_data.head()
print(train_dataset_name)
# Out:
# True
# {'dataset_name': 'healthcare-training-data'}
# healthcare-training-data

# %%
status, job_id = ds.clean_data(train_dataset_name, target=labels_col)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-22T18:06:47.065642', 'endtime': '2019-04-22T18:14:02.827688', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['b42b191667794927b4c356358eea7b72'], 'model_name': None, 'job_error': ''}
# {'job_name': 'a6389521e0b04f7498b4231651a00dbf', 'artifact_name': 'b42b191667794927b4c356358eea7b72'}

# %%
#Create model using cleaned, PCAd training set
model_name= labels_col + "_model0"
status = ds.delete_model(model_name)
print(status)
# Out:
# (True, None)

# %%
status, job_id = ds.create_model(dataset_names='healthcare-training-data', model_name =  model_name, max_train_time = '00:02')
if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 3, 'job_type': 'TrainModel', 'loss': 0.5502675771713257, 'generations': 2, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 3, 'job_type': 'TrainModel', 'loss': 0.5502675771713257, 'generations': 2, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 20, 'job_type': 'TrainModel', 'loss': 0.43903104960918427, 'generations': 2, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 33, 'job_type': 'TrainModel', 'loss': 0.4344262033700943, 'generations': 2, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 42, 'job_type': 'TrainModel', 'loss': 0.43623562157154083, 'generations': 2, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 50, 'job_type': 'TrainModel', 'loss': 0.4118811637163162, 'generations': 3, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': None, 'percent_complete': 66, 'job_type': 'TrainModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-22T19:01:38.946487', 'endtime': '2019-04-22T19:03:37.990114', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}

# %%
test_dataset_name = "healthcare-test-data"

ds.delete_dataset(test_dataset_name)
status, dataset = ds.upload_dataset(test_dataset_filename, test_dataset_name)
if not status:
    print(dataset)

# %%
status, job_id = ds.clean_data(test_dataset_name, target=labels_col)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-22T19:05:23.798727', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['20963b29e0e7432eb67f1127f43ad3ee'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-22T19:05:23.798727', 'endtime': '2019-04-22T19:05:27.121111', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['20963b29e0e7432eb67f1127f43ad3ee'], 'model_name': None, 'job_error': ''}
# {'job_name': '75c867503cc741c4b2181cb53ce79485', 'artifact_name': '20963b29e0e7432eb67f1127f43ad3ee'}

# %%
status, job_id = ds.run_model(test_dataset_name, model_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-22T19:06:15.684501', 'endtime': None, 'percent_complete': 0, 'job_type': 'RunModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['f33b67aff17442cebb207b518a5a5138'], 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-22T19:06:15.684501', 'endtime': None, 'percent_complete': 0, 'job_type': 'RunModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['f33b67aff17442cebb207b518a5a5138'], 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-22T19:06:15.684501', 'endtime': '2019-04-22T19:06:33.575828', 'percent_complete': 100, 'job_type': 'RunModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['f33b67aff17442cebb207b518a5a5138'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'job_name': '4c8b804f9eb84b1e9f102b238e873e19', 'artifact_name': 'f33b67aff17442cebb207b518a5a5138'}

# %%
status, predictions_table = ds.download_artifact(job_id['artifact_name'])
print(predictions_table)
# Out:
#      HPSA_Ind    prob_1    prob_2
# 0           2  0.019662  0.980338
# 1           2  0.247079  0.752921
# 2           2  0.424151  0.575849
# 3           2  0.195084  0.804916
# 4           2  0.000399  0.999601
# 5           2  0.114512  0.885489
# 6           2  0.027436  0.972564
# 7           2  0.134210  0.865790
# 8           2  0.000029  0.999971
# 9           2  0.018267  0.981733
# 10          2  0.029286  0.970714
# 11          2  0.459879  0.540121
# 12          2  0.000000  1.000000
# 13          1  0.554885  0.445115
# 14          2  0.011042  0.988958
# 15          2  0.001210  0.998790
# 16          2  0.032169  0.967831
# 17          1  0.710876  0.289124
# 18          2  0.403445  0.596555
# 19          2  0.005322  0.994678
# 20          1  0.585518  0.414482
# 21          2  0.094231  0.905769
# 22          2  0.004085  0.995915
# 23          2  0.022089  0.977911
# 24          1  0.775945  0.224055
# 25          2  0.325028  0.674972
# 26          2  0.195300  0.804700
# 27          2  0.060613  0.939387
# 28          1  0.508968  0.491032
# 29          2  0.000157  0.999843
# ..        ...       ...       ...
# 370         2  0.392956  0.607044
# 371         2  0.000472  0.999528
# 372         2  0.103390  0.896610
# 373         2  0.141383  0.858617
# 374         1  0.593344  0.406656
# 375         1  0.606786  0.393214
# 376         1  0.640379  0.359621
# 377         2  0.157581  0.842419
# 378         2  0.008559  0.991441
# 379         2  0.140514  0.859486
# 380         2  0.042240  0.957760
# 381         2  0.291927  0.708073
# 382         2  0.012293  0.987707
# 383         2  0.057758  0.942242
# 384         2  0.256895  0.743105
# 385         2  0.076662  0.923338
# 386         2  0.108093  0.891907
# 387         2  0.140165  0.859835
# 388         1  0.509165  0.490835
# 389         2  0.232598  0.767401
# 390         2  0.286115  0.713885
# 391         2  0.264643  0.735357
# 392         2  0.090326  0.909674
# 393         2  0.334476  0.665524
# 394         2  0.004067  0.995933
# 395         2  0.406349  0.593651
# 396         2  0.000004  0.999996
# 397         2  0.370313  0.629687
# 398         2  0.003493  0.996507
# 399         2  0.000363  0.999637
#
# [400 rows x 3 columns]

# %%
predicted_labels = pd.DataFrame(predictions_table)
predicted_labels.to_csv('PREDICTIONS.csv')

# %%
print(test_labels)

# %%
# model_name= labels_col + "_model0" #delete this
# test_dataset_name = "healthcare-test-data" #and this

status, job_id = ds.analyze_predictions(model_name, test_dataset_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Running', 'starttime': '2019-04
# 392           0.030847        0.006104       -0.019862              0.007481
# 393           0.092838        0.000000        0.139557              0.000000
# 394           0.014777        0.005231        0.001494              0.013568
# 395           0.008470        0.000000       -0.022995              0.000000
# 396           0.009782        0.000000        0.027871              0.001244
# 397          -0.034215        0.046772       -0.060534             -0.022853
# 398           0.020498        0.000000        0.003905              0.000000
# 399           0.008569        0.001886        0.006906              0.007422
#
#      White_shap  Black_shap  Native_American_shap       ...         \
# 0      0.000000    0.010239              0.006036       ...
# 1      0.028378   -0.010203              0.000000       ...
# 2     -0.021899    0.000000              0.065062       ...
# 3     -0.020548    0.022793              0.003108       ...
# 4      0.012668    0.000000              0.000000       ...
# 5     -0.010780   -0.011563              0.000000       ...
# 6     -0.027676    0.027634              0.010211       ...
# 7     -0.051598    0.031050              0.000000       ...
# 8      0.008945    0.017261              0.000000       ...
# 9      0.027538   -0.010734              0.003985       ...
# 10     0.034183   -0.021177              0.000000       ...
# 11     0.016649   -0.074285              0.000000       ...
# 12     0.027300    0.029035              0.000000       ...
# 13     0.037963   -0.067776             -0.149071       ...
# 14     0.036174    0.000000              0.005277       ...
# 15     0.000000    0.000000              0.000000       ...
# 16     0.040759   -0.013664              0.003198       ...
# 17     0.098350    0.083007              0.055229       ...
# 18    -0.018647    0.075865              0.029131       ...
# 19     0.020892    0.000000              0.000000       ...
# 20     0.079908   -0.018875              0.022937       ...
# 21     0.031581   -0.017860              0.000000       ...
# 22     0.004849    0.000000              0.000000       ...
# 23     0.000000    0.000000              0.000000       ...
# 24     0.011648   -0.048947             -0.030633       ...
# 25     0.036840   -0.011856             -0.007050       ...
# 26     0.012627   -0.034342              0.011950       ...
# 27     0.000000   -0.021664              0.012815       ...
# 28     0.103095   -0.091743              0.030021       ...
# 29     0.016975    0.018600              0.000000       ...
# ..          ...         ...                   ...       ...
# 370   -0.013486    0.011574              0.013812       ...
# 371    0.014624    0.035309             -0.011158       ...
# 372    0.036895   -0.020308              0.000000       ...
# 373    0.029774    0.082259              0.037224       ...
# 374    0.000000   -0.064091             -0.026640       ...
# 375    0.138525   -0.083404              0.033621       ...
# 376   -0.027575    0.025269              0.000000       ...
# 377   -0.028304    0.021789              0.005834       ...
# 378    0.012265    0.013698              0.005016       ...
# 379   -0.010595    0.011647              0.018686       ...
# 380    0.007575    0.000000              0.000000       ...
# 381    0.216601   -0.107004              0.000000       ...
# 382    0.022258    0.002512              0.005551       ...
# 383    0.002144    0.005444              0.018437       ...
# 384   -0.016177    0.016152              0.012218       ...
# 385    0.021555   -0.019141             -0.004868       ...
# 386    0.000000   -0.012954             -0.014901       ...
# 387    0.030604    0.008379              0.021987       ...
# 388   -0.057394   -0.010904              0.008183       ...
# 389   -0.064422    0.026608              0.015253       ...
# 390   -0.062028    0.073369              0.000000       ...
# 391    0.025578   -0.004908             -0.008246       ...
# 392   -0.101148    0.000000             -0.005536       ...
# 393   -0.050881    0.072202             -0.007861       ...
# 394   -0.007417    0.000000              0.009230       ...
# 383    -0.004816       0.008084        0.000000     0.72125              1.0
# 384     0.007573       0.003417        0.022308     0.72125              1.0
# 385     0.064233      -0.021424        0.002922     0.72125              1.0
# 386     0.000000      -0.010888       -0.006436     0.72125              1.0
# 387     0.013245      -0.011159        0.000000     0.72125              1.0
# 388     0.000000      -0.042637       -0.020369     0.72125              1.0
# 389     0.000000      -0.011523        0.000000     0.72125              1.0
# 390     0.004612      -0.017708        0.000000     0.72125              1.0
# 391     0.181597      -0.007182        0.000000     0.72125              1.0
# 392     0.011304       0.000000        0.015948     0.72125              1.0
# 393     0.016206       0.014130        0.095775     0.72125              1.0
# 394     0.000000       0.039520       -0.006376     0.72125              1.0
# 395    -0.022935       0.000000        0.000000     0.72125              1.0
# 396     0.000000       0.000000        0.003214     0.72125              1.0
# 397     0.000000       0.039451       -0.044563     0.72125              1.0
# 398     0.000000       0.012748        0.000000     0.72125              1.0
# 399     0.000000       0.000000        0.000000     0.72125              1.0
#
#      predicted_class
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  2
# 8                  2
# 9                  2
# 10                 2
# 11                 2
# 12                 2
# 13                 1
# 14                 2
# 15                 2
# 16                 2
# 17                 1
# 18                 2
# 19                 2
# 20                 1
# 21                 2
# 22                 2
# 23                 2
# 24                 1
# 25                 2
# 26                 2
# 27                 2
# 28                 2
# 29                 2
# ..               ...
# 370                2
# 371                2
# 372                2
# 373                2
# 374                1
# 375                1
# 376                1
# 377                2
# 378                2
# 379                2
# 380                2
# 381                2
# 382                2
# 383                2
# 384                2
# 385                2
# 386                2
# 387                2
# 388                2
# 389                2
# 390                2
# 391                2
# 392                2
# 393                2
# 394                2
# 395                2
# 396                2
# 397                2
# 398                2
# 399                2
#
# [400 rows x 56 columns]

# %%
analyze_df = pd.DataFrame(artifact)
analyze_df.head()
# Out:
#    Population_Size_shap  Population_Density_shap  Poverty_shap  \
# 0              0.014703                -0.011839      0.000000
# 1              0.000000                 0.114644     -0.010983
# 2             -0.018126                 0.258513      0.021581
# 3             -0.018835                -0.207816     -0.070931
# 4              0.037151                 0.021388      0.013151
#
#    Age_19_Under_shap  Age_19_64_shap  Age_65_84_shap  Age_85_and_Over_shap  \
# 0           0.038292        0.000000        0.001996              0.005907
# 1           0.023344        0.000000        0.000000              0.003866
# 2           0.097215        0.000000       -0.037017              0.007225
# 3           0.147575       -0.028155        0.095894              0.012150
# 4           0.019190        0.000000        0.011019              0.000000
#
#    White_shap  Black_shap  Native_American_shap       ...         \
# 0    0.000000    0.010239              0.006036       ...
# 1    0.028378   -0.010203              0.000000       ...
# 2   -0.021899    0.000000              0.065062       ...
# 3   -0.020548    0.022793              0.003108       ...
# 4    0.012668    0.000000              0.000000       ...
#
#    Syphilis_Rpt_shap  Syphilis_Exp_shap  No_Exercise_shap  Obesity_shap  \
# 0           0.000000           0.000000          0.052660      0.000000
# 1           0.000000          -0.010495          0.002195     -0.015986
# 2           0.003686          -0.067624          0.000000      0.051913
# 3           0.054949           0.092895          0.038264     -0.057308
# 4           0.005217           0.000000          0.004610     -0.009607
#
#    Smoker_shap  Diabetes_shap  Uninsured_shap  base_value  predicted_proba  \
# 0     0.005155       0.000000        0.005693     0.72125              1.0
# 1    -0.008623       0.000000        0.014296     0.72125              1.0
# 2     0.000000      -0.021264        0.000000     0.72125              1.0
# 3    -0.017418       0.014842       -0.008911     0.72125              1.0
# 4     0.000000      -0.016842        0.000000     0.72125              1.0
#
#    predicted_class
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
#
# [5 rows x 56 columns]

# %%
column_data = analyze_df.drop(columns=['base_value', 'predicted_proba', 'predicted_class'])
print("Column Importance Data")
for column in column_data.columns:
    print(str(column) + ": " + str(column_data[column].mean()))
# Out:
# Column Importance Data
# Population_Size_shap: 0.008961018847930163
# Population_Density_shap: 0.05678539497956317
# Poverty_shap: 0.009428193098287968
# Age_19_Under_shap: 0.017630722346388336
# Age_19_64_shap: 0.00435025680303662
# Age_65_84_shap: 0.00025726065759671047
# Age_85_and_Over_shap: 0.006198769626150065
# White_shap: 0.003571983347610233
# Black_shap: 0.0016088869235694964
# Native_American_shap: 0.004449003247901576
# Asian_shap: 0.006361744938832625
# Hispanic_shap: 0.007766694509772565
# ALE_shap: -0.0017744223138635913
# Health_Status_shap: 0.007460929682949503
# LBW_shap: 0.0029813616663083714
# VLBW_shap: 0.007125379886245651
# Premature_shap: 0.005353393434937015
# Under_18_shap: 0.004663805216831263
# Over_40_shap: 0.0030757211972307135
# Late_Care_shap: 0.0032575649263993007
# Infant_Mortality_shap: 0.008065436576947038
# Unmarried_shap: 0.012535544574332688
# Brst_Cancer_shap: 0.004518590050300394
# Col_Cancer_shap: 0.008933933388768878
# CHD_shap: 0.0012602189068912008
# Lung_Cancer_shap: 0.005966902216526886
# Suicide_shap: 0.009419140175978776
# No_HS_Diploma_shap: 0.003187540215633583
# Unemployed_shap: 0.0013278583660919572
# Sev_Work_Disabled_shap: 0.004403177894125048
# Major_Depression_shap: 0.0036826904473750755
# Recent_Drug_Use_shap: 0.004095235626265566
# Ecol_Rpt_shap: 0.0018041807149424005
# Ecol_Exp_shap: 0.019632692158879247
# Salm_Rpt_shap: 0.010389366502241672
# Salm_Exp_shap: -0.0005268037230123092
# Shig_Rpt_shap: 0.002432396969586263
# Shig_Exp_shap: 0.0019185871204174406
# FluB_Rpt_shap: 0.005202133452822836
# FluB_Exp_shap: 0.004085507409778216
# HepA_Rpt_shap: 0.0048614998714581895
# HepA_Exp_shap: 0.003794813477090553
# HepB_Rpt_shap: 0.005187151312428107
# HepB_Exp_shap: 0.005442959290388587
# Pert_Rpt_shap: 0.0015125997762264016
# Pert_Exp_shap: 0.010683376969816622
# Syphilis_Rpt_shap: 0.00317156659808578
# Syphilis_Exp_shap: 0.0022462663509433636
# No_Exercise_shap: 0.0030652796408323028
# Obesity_shap: 0.01151856826679487
# Smoker_shap: 0.0031267015145930643
# Diabetes_shap: 0.003243243099190924
# Uninsured_shap: 0.0054667317635806725

# %%
accuracy_score = sk.metrics.accuracy_score(test_labels,predicted_labels[labels_col])
print(accuracy_score)
# Out:
# 0.77

# %%
status, job_id = ds.analyze_model(model_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-22T19:53:10.815742', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': None, 'artifact_names': ['1efb367abb17413baf053c0357154999'], 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-22T19:53:10.815742', 'endtime': '2019-04-22T19:53:12.228108', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': 0.4118811637163162, 'generations': 5, 'dataset_names': None, 'artifact_names': ['1efb367abb17413baf053c0357154999'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'job_name': 'b0ed6a4ab5504e1cb8bbe8ad2703c559', 'artifact_name': '1efb367abb17413baf053c0357154999'}

# %%
status, artifact = ds.download_artifact(job_id['artifact_name'])
print(artifact)
# Out:
# Population_Size       0.094101
# Ecol_Exp              0.055473
# Age_19_Under          0.044068
# Population_Density    0.040364
# FluB_Exp              0.034314
# Age_85_and_Over       0.033658
# Poverty               0.029848
# Age_65_84             0.027963
# White                 0.024928
# Salm_Rpt              0.024074
# HepA_Exp              0.020650
# Ecol_Rpt              0.019069
# VLBW                  0.018840
# Unmarried             0.018523
# Hispanic              0.018442
# FluB_Rpt              0.017444
# Health_Status         0.017385
# Asian                 0.017379
# No_HS_Diploma         0.017303
# Infant_Mortality      0.017226
# No_Exercise           0.017155
# Suicide               0.016859
# Syphilis_Exp          0.016347
# Late_Care             0.016153
# Recent_Drug_Use       0.015946
# Native_American       0.015786
# Premature             0.015156
# ALE                   0.015030
# Age_19_64             0.014520
# HepB_Exp              0.014473
# Shig_Exp              0.014201
# LBW                   0.014174
# Under_18              0.014108
# Syphilis_Rpt          0.013586
# Uninsured             0.013485
# HepA_Rpt              0.013272
# Over_40               0.013122
# Lung_Cancer           0.013103
# Salm_Exp              0.012737
# HepB_Rpt              0.012536
# Shig_Rpt              0.011918
# Diabetes              0.010740
# Pert_Exp              0.010077
# Unemployed            0.010044
# Brst_Cancer           0.009497
# Major_Depression      0.009048
# Smoker                0.008626
# Pert_Rpt              0.008609
# CHD                   0.008581
# Col_Cancer            0.008108
# Black                 0.007650
# Sev_Work_Disabled     0.007578
# Obesity               0.006720
# dtype: float64

# %%
print("Confusion Matrix")
print(confusion_matrix(test_labels,predicted_labels[labels_col]))
print(classification_report(test_labels, predicted_labels[labels_col]))
# Out:
# Confusion Matrix
# [[ 27  56]
#  [ 36 281]]
#               precision    recall  f1-score   support
#
#            1       0.43      0.33      0.37        83
#            2       0.83      0.89      0.86       317
#
#    micro avg       0.77      0.77      0.77       400
#    macro avg       0.63      0.61      0.61       400
# weighted avg       0.75      0.77      0.76       400
