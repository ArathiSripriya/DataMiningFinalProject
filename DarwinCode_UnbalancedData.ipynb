# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
from time import sleep
import os
import numpy as np
import sklearn as sk
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
import time

from amb_sdk.sdk import DarwinSdk

# %%
# Login
ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
ds.auth_login_user('vargasbri2@gmail.com', 'qNuNeX5JGY')
# Out:
# (True,
#  'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1NTYwNzk2NzgsImlhdCI6MTU1NjA3MjQ3OCwibmJmIjoxNTU2MDcyNDc4LCJqdGkiOiIzNTNjMjI2OC02NThiLTQwYmYtOGY2OS1jY2E5MmIzNTRkNjIiLCJpZGVudGl0eSI6Ijc2NmRiM2JjLTRmMzUtMTFlOS1iMzEwLTc3ZWRkN2EzNzNhOSIsImZyZXNoIjpmYWxzZSwidHlwZSI6ImFjY2VzcyJ9.UH6hFGt9hil1mZgVSletI2jr8_Av5e_ImSufte0AMrw')

# %%
"""Removing Meas_Rpt, Meas_Exp, CRS_Rpt, CRS_Exp because not a lot of varying data
Removing for too many missing values: High_Blood_Pres (0.515441), Few_Fruit_Veg (0.393824)
Removed state and county names because not numerical"""

df_list = []
labels_col = 'HPSA_Ind'
base_path = 'chsi_dataset/'
newdata_path = 'unbalanced/'

def create_new_df(dataset_name, column_names):
    df = pd.read_csv(dataset_name)
    return df[column_names]

"""Creates new column to act as unique key to merge on. 
This new column, called State_And_County_FIPS_Code
is formatted as <State_FIPS_Code>-<County_FIPS_Code>.
The original columns for State_FIPS_Code and County_FIPS_Code are then removed."""

def merge_state_and_county_codes(df):
    df["State_And_County_FIPS_Code"] = df["State_FIPS_Code"].map(str) + "-" + df["County_FIPS_Code"].map(str)
    df = df.drop(columns = ['State_FIPS_Code', 'County_FIPS_Code'])
    return df

#Creates aggregated dataset from original six datsets in chsi
def sample_help():
    global df_list
    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'Population_Size','Population_Density','Poverty','Age_19_Under','Age_19_64','Age_65_84','Age_85_and_Over','White','Black','Native_American','Asian','Hispanic']
    demographics_df = create_new_df(base_path + "DEMOGRAPHICS.csv", col_names)
    df_list.append(demographics_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'ALE', 'Health_Status']
    summ_meas_health_df = create_new_df(base_path + "SUMMARYMEASURESOFHEALTH.csv", col_names)
    df_list.append(summ_meas_health_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'LBW','VLBW','Premature','Under_18','Over_40','Late_Care','Infant_Mortality','Unmarried','Brst_Cancer','Col_Cancer','CHD','Lung_Cancer','Suicide']
    meas_birth_and_death_df = create_new_df(base_path + "MEASURESOFBIRTHANDDEATH.csv", col_names)
    df_list.append(meas_birth_and_death_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'No_HS_Diploma','Unemployed','Sev_Work_Disabled','Major_Depression','Recent_Drug_Use','Ecol_Rpt','Ecol_Exp','Salm_Rpt','Salm_Exp','Shig_Rpt','Shig_Exp']
    vuln_pop_and_env_health_df = create_new_df(base_path + "VUNERABLEPOPSANDENVHEALTH.csv", col_names)
    df_list.append(vuln_pop_and_env_health_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'FluB_Rpt','FluB_Exp','HepA_Rpt','HepA_Exp','HepB_Rpt','HepB_Exp','Pert_Rpt','Pert_Exp','Syphilis_Rpt','Syphilis_Exp']
    prev_services_df = create_new_df(base_path + "PREVENTIVESERVICESUSE.csv", col_names)
    df_list.append(prev_services_df)

    col_names = ['State_FIPS_Code', 'County_FIPS_Code', 'No_Exercise','Obesity','Smoker','Diabetes','Uninsured', labels_col]
    risk_factors_df = create_new_df(base_path + "RISKFACTORSANDACCESSTOCARE.csv", col_names)
    df_list.append(risk_factors_df)
    
    #Merges State and County Codes for each df
    for df_idx in range(len(df_list)):
        df_list[df_idx] = merge_state_and_county_codes(df_list[df_idx])
        
#Creates a sampled dataset on size n from aggregate dataset
def my_sample(n):
    global df_list
    sample_help()
    df_list = [df.set_index("State_And_County_FIPS_Code") for df in df_list]
    merged_df = df_list[0].join(df_list[1:])
    smaller_sample = merged_df.sample(n)
    smaller_sample.head()
    smaller_sample.to_csv(newdata_path + 'SAMPLEDDATASET.csv')
    
#This call was to create the sampled dataset. It is commented out for subsequent runs.
# my_sample(2000)

# %%
#START HERE - after creating SAMPLEDDATASET
#Read sampled dataset into DataFrame
filename = newdata_path + 'SAMPLEDDATASET.csv'
merged_df = pd.read_csv(filename, index_col='State_And_County_FIPS_Code')

# %%
#Replace error values with NaN for imputation handling
merged_df = merged_df.replace([-9999, -9998.9, -2222.2, -2222, -1111.1, -1111, -2, -1], np.nan)
merged_df.head()
# Out:
#                             Population_Size  Population_Density  Poverty  \
# State_And_County_FIPS_Code
# 48-267                                 4591                   4     17.1
# 5-129                                  7969                  12     21.8
# 48-481                                41554                  38     15.6
# 26-39                                 15074                  27     12.5
# 45-35                                112858                 196     11.2
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                              23.1       57.2       17.6
# 5-129                               20.9       59.3       16.9
# 48-481                              28.8       57.5       11.8
# 26-39                               22.3       61.1       14.6
# 45-35                               26.6       63.9        8.6
#
#                             Age_85_and_Over  White  Black  Native_American  \
# State_And_County_FIPS_Code
# 48-267                                  2.0   98.3    0.5              0.4
# 5-129                                   2.9   98.0    0.2              0.8
# 48-481                                  1.8   84.2   14.5              0.5
# 26-39                                   2.0   95.9    2.5              0.7
# 45-35                                   1.0   71.4   25.2              0.7
#
#                               ...     Pert_Rpt  Pert_Exp  Syphilis_Rpt  \
# State_And_County_FIPS_Code    ...
# 48-267                        ...            0         3             0
# 5-129                         ...           21         2             0
# 48-481                        ...            1         6             8
# 26-39                         ...            1         1             0
# 45-35                         ...           12        10             4
#
#                             Syphilis_Exp  No_Exercise  Obesity  Smoker  \
# State_And_County_FIPS_Code
# 48-267                                 0          NaN      NaN     NaN
# 5-129                                  1         28.6      NaN    23.5
# 48-481                                 4          NaN      NaN    15.6
# 26-39                                  4          NaN      NaN     NaN
# 45-35                                  5         25.3     27.0    22.1
#
#                             Diabetes  Uninsured  HPSA_Ind
# State_And_County_FIPS_Code
# 48-267                           NaN      965.0         2
# 5-129                           12.4     2118.0         2
# 48-481                          11.8     7845.0         2
# 26-39                           10.3     1973.0         2
# 45-35                            7.1    12899.0         2
#
# [5 rows x 54 columns]

# %%
#Imputation to handle missing values (represented as NaN) in data
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
filled_data = imp.fit_transform(merged_df)
filled_df = pd.DataFrame(filled_data, columns=merged_df.columns)

#Save features and labels separately for feature engineering
df_feats = filled_df.loc[:, filled_df.columns != labels_col]
df_labels = merged_df.iloc[:, merged_df.columns == labels_col]
df_feats.head()
# Out:
#    Population_Size  Population_Density  Poverty  Age_19_Under  Age_19_64  \
# 0           4591.0                 4.0     17.1          23.1       57.2
# 1           7969.0                12.0     21.8          20.9       59.3
# 2          41554.0                38.0     15.6          28.8       57.5
# 3          15074.0                27.0     12.5          22.3       61.1
# 4         112858.0               196.0     11.2          26.6       63.9
#
#    Age_65_84  Age_85_and_Over  White  Black  Native_American    ...      \
# 0       17.6              2.0   98.3    0.5              0.4    ...
# 1       16.9              2.9   98.0    0.2              0.8    ...
# 2       11.8              1.8   84.2   14.5              0.5    ...
# 3       14.6              2.0   95.9    2.5              0.7    ...
# 4        8.6              1.0   71.4   25.2              0.7    ...
#
#    HepB_Exp  Pert_Rpt  Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# 0       2.0       0.0       3.0           0.0           0.0    26.633262
# 1       2.0      21.0       2.0           0.0           1.0    28.600000
# 2       4.0       1.0       6.0           8.0           4.0    26.633262
# 3       4.0       1.0       1.0           0.0           4.0    26.633262
# 4      15.0      12.0      10.0           4.0           5.0    25.300000
#
#      Obesity    Smoker   Diabetes  Uninsured
# 0  24.168887  23.11587   7.796638      965.0
# 1  24.168887  23.50000  12.400000     2118.0
# 2  24.168887  15.60000  11.800000     7845.0
# 3  24.168887  23.11587  10.300000     1973.0
# 4  27.000000  22.10000   7.100000    12899.0
#
# [5 rows x 53 columns]

# %%
#Perform standardization
scaler = sk.preprocessing.StandardScaler(with_mean=0, with_std=1)
standardized_data = scaler.fit_transform(df_feats)
standardized_df = pd.DataFrame(standardized_data, columns=df_feats.columns, index=merged_df.index)
standardized_df.head()
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 48-267                             0.014481            0.003833  3.477367
# 5-129                              0.025136            0.011498  4.433135
# 48-481                             0.131071            0.036411  3.172335
# 26-39                              0.047547            0.025871  2.541935
# 45-35                              0.355980            0.187804  2.277574
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                          7.181861  16.667614   5.333130
# 5-129                           6.497874  17.279537   5.121017
# 48-481                          8.954008  16.755032   3.575622
# 26-39                           6.933138  17.804042   4.424074
# 45-35                           8.270021  18.619940   2.605961
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 48-267                             2.117243  6.135751  0.034151
# 5-129                              3.070002  6.117025  0.013660
# 48-481                             1.905518  5.255648  0.990370
# 26-39                              2.117243  5.985946  0.170754
# 45-35                              1.058621  4.456690  1.721196
#
#                             Native_American    ...      HepB_Exp  Pert_Rpt  \
# State_And_County_FIPS_Code                     ...
# 48-267                             0.059450    ...      0.072501  0.000000
# 5-129                              0.118900    ...      0.072501  0.548360
# 48-481                             0.074313    ...      0.145003  0.026112
# 26-39                              0.104038    ...      0.145003  0.026112
# 45-35                              0.104038    ...      0.543760  0.313349
#
#                             Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# State_And_County_FIPS_Code
# 48-267                      0.107772       0.00000      0.000000     4.754315
# 5-129                       0.071848       0.00000      0.027419     5.105399
# 48-481                      0.215545       0.16844      0.109676     4.754315
# 26-39                       0.035924       0.00000      0.109676     4.754315
# 45-35                       0.359242       0.08422      0.137095     4.516314
#
#                              Obesity    Smoker  Diabetes  Uninsured
# State_And_County_FIPS_Code
# 48-267                      5.877071  4.667118  3.073575   0.016117
# 5-129                       5.877071  4.744674  4.888304   0.035374
# 48-481                      5.877071  3.149656  4.651773   0.131024
# 26-39                       5.877071  4.667118  4.060446   0.032952
# 45-35                       6.565504  4.462013  2.798948   0.215434
#
# [5 rows x 53 columns]

# %%
#Perform PCA to reduce dimensionality
pca = PCA()

pca_data = pca.fit_transform(standardized_df)
pca_df = pd.DataFrame(pca_data, columns=standardized_df.columns, index=merged_df.index)
pca_df.head()
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 48-267                            -1.566259            0.560488  1.384149
# 5-129                             -1.724290            1.749549  2.690684
# 48-481                            -0.607729            1.181050 -0.494776
# 26-39                             -1.374806            0.848758  0.604481
# 45-35                              0.925710            0.997256 -2.226410
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                          2.537828   0.746897  -0.212123
# 5-129                          -0.408630   0.086359  -0.712735
# 48-481                          3.585611  -0.045433  -0.219206
# 26-39                          -0.790270   0.797244   0.894896
# 45-35                          -1.105993  -0.525132   0.820031
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 48-267                            -0.898175  1.055979 -0.332058
# 5-129                              0.025589  1.764069 -1.797602
# 48-481                            -1.677337  0.141064 -0.034358
# 26-39                              0.963442  0.710223 -0.328074
# 45-35                             -0.501999 -0.607889  0.270041
#
#                             Native_American    ...      HepB_Exp  Pert_Rpt  \
# State_And_County_FIPS_Code                     ...
# 48-267                            -0.743536    ...      0.015112  0.008016
# 5-129                              0.013359    ...      0.064116  0.042749
# 48-481                            -0.102473    ...      0.047867 -0.035978
# 26-39                              0.339749    ...     -0.038447 -0.048551
# 45-35                              1.427288    ...     -0.139831 -0.015536
#
#                             Pert_Exp  Syphilis_Rpt  Syphilis_Exp  No_Exercise  \
# State_And_County_FIPS_Code
# 48-267                     -0.100886      0.004580      0.027538    -0.022406
# 5-129                      -0.002686     -0.016248      0.083492     0.001213
# 48-481                     -0.039264      0.047840     -0.072165     0.028307
# 26-39                       0.165967     -0.029711      0.020112    -0.018684
# 45-35                       0.228784     -0.046414     -0.061755    -0.070643
#
#                              Obesity    Smoker  Diabetes  Uninsured
# State_And_County_FIPS_Code
# 48-267                      0.036761 -0.022201 -0.000262   0.013927
# 5-129                       0.008180  0.007419 -0.011467  -0.000126
# 48-481                     -0.036187 -0.012980  0.008641   0.019483
# 26-39                       0.027932 -0.011239 -0.002515  -0.002862
# 45-35                       0.154130  0.006802  0.027216  -0.017928
#
# [5 rows x 53 columns]

# %%
#Concatenate original labels that were removed for standardization and PCA
pca_df = pca_df.join(df_labels[labels_col])
pca_df.head()
# Out:
#                             Population_Size  Population_Density   Poverty  \
# State_And_County_FIPS_Code
# 48-267                            -1.566259            0.560488  1.384149
# 5-129                             -1.724290            1.749549  2.690684
# 48-481                            -0.607729            1.181050 -0.494776
# 26-39                             -1.374806            0.848758  0.604481
# 45-35                              0.925710            0.997256 -2.226410
#
#                             Age_19_Under  Age_19_64  Age_65_84  \
# State_And_County_FIPS_Code
# 48-267                          2.537828   0.746897  -0.212123
# 5-129                          -0.408630   0.086359  -0.712735
# 48-481                          3.585611  -0.045433  -0.219206
# 26-39                          -0.790270   0.797244   0.894896
# 45-35                          -1.105993  -0.525132   0.820031
#
#                             Age_85_and_Over     White     Black  \
# State_And_County_FIPS_Code
# 48-267                            -0.898175  1.055979 -0.332058
# 5-129                              0.025589  1.764069 -1.797602
# 48-481                            -1.677337  0.141064 -0.034358
# 26-39                              0.963442  0.710223 -0.328074
# 45-35                             -0.501999 -0.607889  0.270041
#
#                             Native_American    ...     Pert_Rpt  Pert_Exp  \
# State_And_County_FIPS_Code                     ...
# 48-267                            -0.743536    ...     0.008016 -0.100886
# 5-129                              0.013359    ...     0.042749 -0.002686
# 48-481                            -0.102473    ...    -0.035978 -0.039264
# 26-39                              0.339749    ...    -0.048551  0.165967
# 45-35                              1.427288    ...    -0.015536  0.228784
#
#                             Syphilis_Rpt  Syphilis_Exp  No_Exercise   Obesity  \
# State_And_County_FIPS_Code
# 48-267                          0.004580      0.027538    -0.022406  0.036761
# 5-129                          -0.016248      0.083492     0.001213  0.008180
# 48-481                          0.047840     -0.072165     0.028307 -0.036187
# 26-39                          -0.029711      0.020112    -0.018684  0.027932
# 45-35                          -0.046414     -0.061755    -0.070643  0.154130
#
#                               Smoker  Diabetes  Uninsured  HPSA_Ind
# State_And_County_FIPS_Code
# 48-267                     -0.022201 -0.000262   0.013927         2
# 5-129                       0.007419 -0.011467  -0.000126         2
# 48-481                     -0.012980  0.008641   0.019483         2
# 26-39                      -0.011239 -0.002515  -0.002862         2
# 45-35                       0.006802  0.027216  -0.017928         2
#
# [5 rows x 54 columns]

# %%
#Split Data
data_feats = pca_df.loc[:, pca_df.columns != labels_col]
data_labels = pca_df.iloc[:, pca_df.columns == labels_col]

#Using 80-20 split
train_feats,test_feats, train_labels, test_labels = sk.model_selection.train_test_split(data_feats, data_labels, test_size=0.2)
train_data = train_feats.join(train_labels)
test_data = test_feats.join(test_labels)

train_dataset_filename = newdata_path + "TRAINDATA.csv"
test_dataset_filename = newdata_path + "TESTDATA.csv" 

train_data.to_csv(train_dataset_filename)
test_data.to_csv(test_dataset_filename)

# %%
#Upload training dataset to Darwin (delete first if a dataset with this name already exists)
train_dataset_name = "healthcare-training-data"

status, dataset = ds.delete_dataset(train_dataset_name)
status, dataset = ds.upload_dataset(train_dataset_filename, train_dataset_name)
if not status:
    print(dataset)

# %%
#Use Darwin to clean training data
status, job_id = ds.clean_data(train_dataset_name, target=labels_col)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Taken', 'starttime': '2019-04-23T20:33:03.937838', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['2d457a5f9ae34da3bd26b350d2db717f'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-23T20:33:03.937838', 'endtime': '2019-04-23T20:33:07.794328', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-training-data'], 'artifact_names': ['2d457a5f9ae34da3bd26b350d2db717f'], 'model_name': None, 'job_error': ''}
# {'job_name': 'b853a06603054c768ed8d0c41e482b7b', 'artifact_name': '2d457a5f9ae34da3bd26b350d2db717f'}

# %%
#Delete existing model under this name
model_name= labels_col + "_model0"
status = ds.delete_model(model_name)
print(status)
# Out:
# (True, None)

# %%
#Create model using cleaned training set
status, job_id = ds.create_model(dataset_names='healthcare-training-data', model_name =  model_name, max_train_time = '00:02')
if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Requested', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': 0.5441399812698364, 'generations': 0, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 9, 'job_type': 'TrainModel', 'loss': 0.5370314121246338, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 9, 'job_type': 'TrainModel', 'loss': 0.5370314121246338, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 9, 'job_type': 'TrainModel', 'loss': 0.5370314121246338, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 20, 'job_type': 'TrainModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 28, 'job_type': 'TrainModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': None, 'percent_complete': 42, 'job_type': 'TrainModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-23T20:33:30.123749', 'endtime': '2019-04-23T20:35:41.645118', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-training-data'], 'artifact_names': None, 'model_name': 'HPSA_Ind_model0', 'job_error': ''}

# %%
#Upload our held-out test dataset to Darwin (first delete any existing dataset under same name)
test_dataset_name = "healthcare-test-data"

ds.delete_dataset(test_dataset_name)
status, dataset = ds.upload_dataset(test_dataset_filename, test_dataset_name)
if not status:
    print(dataset)

# %%
#Use Darwin to clean our held-out test dataset
status, job_id = ds.clean_data(test_dataset_name, target=labels_col)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Taken', 'starttime': '2019-04-23T20:36:27.195009', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['3d23483fec064c7c92b568872b24fbff'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-23T20:36:27.195009', 'endtime': '2019-04-23T20:36:30.108512', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['3d23483fec064c7c92b568872b24fbff'], 'model_name': None, 'job_error': ''}
# {'job_name': 'e9bd7730e44f47bdb57a34c9dbdefdac', 'artifact_name': '3d23483fec064c7c92b568872b24fbff'}

# %%
#Run model against our held-out test dataset
status, job_id = ds.run_model(test_dataset_name, model_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-23T20:36:48.89244', 'endtime': None, 'percent_complete': 0, 'job_type': 'RunModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['278ec25e6b88478da99868252645d52c'], 'model_name': 'HPSA_Ind_model0', 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-23T20:36:48.89244', 'endtime': '2019-04-23T20:36:50.348656', 'percent_complete': 100, 'job_type': 'RunModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': ['healthcare-test-data'], 'artifact_names': ['278ec25e6b88478da99868252645d52c'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'job_name': '77c403958b0b430abb8d85c4bc0a3395', 'artifact_name': '278ec25e6b88478da99868252645d52c'}

# %%
#Prints results of run_model which include the predictions of test data labels
#as well as the respective probabilities of each class
status, predictions_table = ds.download_artifact(job_id['artifact_name'])
print(predictions_table)
# Out:
#      HPSA_Ind    prob_1    prob_2
# 0           2  0.370016  0.629984
# 1           2  0.327410  0.672590
# 2           1  0.606327  0.393673
# 3           2  0.138318  0.861682
# 4           2  0.019051  0.980949
# 5           2  0.005490  0.994510
# 6           2  0.362254  0.637746
# 7           2  0.288496  0.711504
# 8           2  0.258849  0.741151
# 9           2  0.269998  0.730002
# 10          2  0.092749  0.907251
# 11          2  0.367230  0.632770
# 12          2  0.210618  0.789382
# 13          2  0.452807  0.547193
# 14          2  0.215839  0.784161
# 15          2  0.161212  0.838788
# 16          2  0.116287  0.883713
# 17          2  0.221415  0.778585
# 18          2  0.294185  0.705815
# 19          2  0.147978  0.852022
# 20          2  0.031545  0.968455
# 21          2  0.201397  0.798603
# 22          2  0.046185  0.953815
# 23          2  0.017072  0.982928
# 24          2  0.050010  0.949990
# 25          2  0.313226  0.686774
# 26          2  0.176131  0.823869
# 27          2  0.495481  0.504519
# 28          2  0.149382  0.850618
# 29          2  0.099294  0.900706
# ..        ...       ...       ...
# 370         2  0.175571  0.824429
# 371         2  0.191614  0.808386
# 372         2  0.028321  0.971679
# 373         2  0.426660  0.573340
# 374         1  0.529125  0.470875
# 375         1  0.629940  0.370060
# 376         2  0.362475  0.637525
# 377         1  0.583795  0.416205
# 378         2  0.300700  0.699300
# 379         2  0.196838  0.803162
# 380         2  0.275555  0.724445
# 381         2  0.053916  0.946084
# 382         2  0.063564  0.936436
# 383         2  0.273008  0.726992
# 384         2  0.475607  0.524393
# 385         2  0.427679  0.572321
# 386         2  0.266780  0.733220
# 387         2  0.438419  0.561581
# 388         2  0.200426  0.799574
# 389         2  0.119559  0.880441
# 390         2  0.283206  0.716794
# 391         2  0.048781  0.951219
# 392         2  0.202925  0.797075
# 393         1  0.521974  0.478026
# 394         2  0.289814  0.710186
# 395         2  0.182372  0.817628
# 396         2  0.399900  0.600100
# 397         2  0.253644  0.746356
# 398         2  0.236756  0.763244
# 399         2  0.365386  0.634614
#
# [400 rows x 3 columns]

# %%
#Write predicted labels to CSV
predicted_labels = pd.DataFrame(predictions_table)
predicted_labels.to_csv(newdata_path + 'PREDICTIONS.csv')

# %%
#Use Darwin to analyze predictions
status, job_id = ds.analyze_predictions(model_name, test_dataset_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-23T21:21:33.597901', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzePredictions', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['807cad5fc72f40ac876d5486856652b1'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'job_name': '3640b468771e42e9851b4643e7ffce03', 'artifact_name': '807cad5fc72f40ac876d5486856652b1'}

# %%
#Print results of analyze_predictions call
status, artifact = ds.download_artifact(job_id['artifact_name'])
print(artifact)
analyze_df = pd.DataFrame(artifact)
analyze_df.head()
# Out:
# 404: NOT FOUND - {"message": "Failed to find artifact 807cad5fc72f40ac876d5486856652b1"}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-5f87f231d0b4> in <module>
#       2 status, artifact = ds.download_artifact(job_id['artifact_name'])
#       3 print(artifact)
# ----> 4 analyze_df = pd.DataFrame(artifact)
#       5 analyze_df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
#Print accuracy score of run_model results on test data
accuracy_score = sk.metrics.accuracy_score(test_labels,predicted_labels[labels_col])
print(accuracy_score)
# Out:
# 0.8

# %%
#Use Darwin to analyze the model we created, trained, and tested
status, job_id = ds.analyze_model(model_name)
if status:
    ds.wait_for_job(job_id['job_name'])
print(job_id)
# Out:
# {'status': 'Running', 'starttime': '2019-04-23T21:11:03.733133', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['9a9f67e8c8cd4f9ca198175b70c152e9'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-23T21:11:03.733133', 'endtime': '2019-04-23T21:11:11.789688', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': 0.4792640805244446, 'generations': 6, 'dataset_names': None, 'artifact_names': ['9a9f67e8c8cd4f9ca198175b70c152e9'], 'model_name': 'HPSA_Ind_model0', 'job_error': ''}
# {'job_name': '983aca2ec9c0464ca4ba584ace40c525', 'artifact_name': '9a9f67e8c8cd4f9ca198175b70c152e9'}

# %%
#Print results of analyze_model showing the importance of each feature in our dataset
status, artifact = ds.download_artifact(job_id['artifact_name'])
print(artifact)
# Out:
# Age_65_84             0.071281
# Ecol_Exp              0.062909
# Population_Size       0.055126
# Population_Density    0.041907
# Age_85_and_Over       0.036993
# Ecol_Rpt              0.031320
# Salm_Rpt              0.029716
# Age_19_Under          0.027866
# Hispanic              0.027712
# Infant_Mortality      0.027387
# VLBW                  0.023658
# Recent_Drug_Use       0.023086
# Brst_Cancer           0.022695
# Unemployed            0.022638
# Suicide               0.021225
# Age_19_64             0.019379
# Health_Status         0.017476
# Salm_Exp              0.017229
# Shig_Exp              0.017070
# Poverty               0.016694
# Uninsured             0.016059
# No_HS_Diploma         0.015897
# Unmarried             0.015442
# FluB_Exp              0.015323
# Late_Care             0.015226
# Syphilis_Exp          0.015079
# HepB_Exp              0.015014
# FluB_Rpt              0.014901
# Syphilis_Rpt          0.014706
# HepA_Exp              0.014487
# Native_American       0.014211
# LBW                   0.013590
# Lung_Cancer           0.013254
# White                 0.012666
# No_Exercise           0.012398
# HepB_Rpt              0.011723
# Pert_Exp              0.011709
# Sev_Work_Disabled     0.011126
# Obesity               0.011019
# CHD                   0.010964
# Shig_Rpt              0.010846
# Under_18              0.010598
# Col_Cancer            0.010393
# Asian                 0.010184
# Premature             0.009993
# Pert_Rpt              0.009786
# ALE                   0.009182
# Smoker                0.008490
# Diabetes              0.007703
# HepA_Rpt              0.007449
# Black                 0.007236
# Over_40               0.006085
# Major_Depression      0.003894
# dtype: float64

# %%
#Print confusion matrix and classification report of our model results
print("Confusion Matrix")
print(confusion_matrix(test_labels,predicted_labels[labels_col]))
print("\nClassification Report")
print(classification_report(test_labels, predicted_labels[labels_col]))
# Out:
# Confusion Matrix
# [[ 24  71]
#  [  9 296]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.73      0.25      0.38        95
#            2       0.81      0.97      0.88       305
#
#    micro avg       0.80      0.80      0.80       400
#    macro avg       0.77      0.61      0.63       400
# weighted avg       0.79      0.80      0.76       400
